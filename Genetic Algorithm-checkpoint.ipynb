# %%
import random
import string

target = "HELLO, WORLD!"

ps = 200
mr = 0.01

def generate_random_string(length):
    return ''.join(random.choice(string.printable) for _ in range(length))

def calculate_fitness(string):
    return sum(1 for a, b in zip(string, target) if a == b)

def select(population):
    total_fitness = sum(calculate_fitness(ind) for ind in population)
    r = random.uniform(0, total_fitness)
    current_sum = 0
    for ind in population:
        current_sum += calculate_fitness(ind)
        if current_sum >= r:
            return ind

def create_new_generation(population):
    new_population = []
    for _ in range(ps):
        parent1 = select(population)
        parent2 = select(population)
        split_point = random.randint(1, len(target) - 1)
        child = parent1[:split_point] + parent2[split_point:]
        for i in range(len(child)):
            if random.random() < mr:
                child = child[:i] + random.choice(string.printable) + child[i+1:]
        new_population.append(child)
    return new_population

population = [generate_random_string(len(target)) for _ in range(ps)]
generation = 1

while True:
    population.sort(key=lambda x: -calculate_fitness(x))
    best_individual = population[0]
    print(f"Generation {generation}: {best_individual}")
    if best_individual == target:
        break
    population = create_new_generation(population)
    generation += 1
# Out:
# Generation 1: BEDGQr|ihHW6Q
# Generation 2: ^E#MK	nlyJLV\
# Generation 3: 1L_L
# H 6OYdDm
# Generation 4: BED(5, 6O9dDm
# Generation 5: BED(5, 6O9L*\
# Generation 6: ^EIMC, COV^Ds
# Generation 7: BEDL
# , Cv8^Dm
# Generation 8: zEYLK, COVdDm
# Generation 9: 1EbL
# , \HRdDJ
# Generation 10: BELL
# H COV^D:
# Generation 11: BEDL
# , CORdDJ
# Generation 12: ^ELL
# , CO7dDm
# Generation 13: CELL^, uO9LDJ
# Generation 14: BELL^, uO9LDJ
# Generation 15: BELL^, uO9LDJ
# Generation 16: BELL
# , 6ORdDs
# Generation 17: *ELL
# , 6ORdDp
# Generation 18: BELL
# , 6ORrDm
# Generation 19: BELLO, COVdDm
# Generation 20: 1EILO, 6OR^D(
# Generation 21: dELL9, CORvDm
# Generation 22: *ELLO, GORdDm
# Generation 23: *ELLO, GORdD(
# Generation 24: *ELLO, lORdDm
# Generation 25: *ELLO, CORvDm
# Generation 26: *ELLO, CORvDm
# Generation 27: *ELLO, WORdDJ
# Generation 28: *ELLO, WORdDJ
# Generation 29: *ELLO, WORdDm
# Generation 30: *ELLO, WORdD(
# Generation 31: 1ELLO, WORdDs
# Generation 32: *ELLO, WORdDs
# Generation 33: *ELLO, WORdDs
# Generation 34: 1ELLO, WORdDs
# Generation 35: *ELLO, WORrDs
# Generation 36: 1ELLO, WORdD(
# Generation 37: 1ELLO, WOR^Dp
# Generation 38: *ELLO, WORDDm
# Generation 39: 1ELLO, WORdDs
# Generation 40: FELLO, WORvDs
# Generation 41: *ELLO, WOR}Dy
# Generation 42: 1ELLO, WORdDp
# Generation 43: tELLO, WORdD:
# Generation 44: "ELLO, WORgDk
# Generation 45: *ELLO, WORdDm
# Generation 46: "ELLO, WORDD(
# Generation 47: FELLO, WOR^D(
# Generation 48: 1ELLO, WORvD(
# Generation 49: *ELLO, WORLDy
# Generation 50: *ELLO, WORLDK
# Generation 51: 1ELLO, WORvDm
# Generation 52: tELLO, WORdDs
# Generation 53: *ELLO, WOR!Ds
# Generation 54: *ELLO, WORDD,
# Generation 55: 5ELLO, WORSDm
# Generation 56: 7ELLO, WOR^Ds
# Generation 57: 7ELLO, WORDD,
# Generation 58: FELLO, WORSDm
# Generation 59: EELLO, WORdD1
# Generation 60: tELLO, WORdDm
# Generation 61: 5ELLO, WOR^Ds
# Generation 62: tELLO, WORdDs
# Generation 63: HELLO, WORdDy
# Generation 64: 7ELLOg WORdD!
# Generation 65: *ELLO, WOR%Dh
# Generation 66: *ELLO, WORdD!
# Generation 67: VELLO, WORdD!
# Generation 68: VELLO, WORdD!
# Generation 69: *ELLO, WOR8Dm
# Generation 70: 7ELLO, WORDDm
# Generation 71: 5ELLO, WOR^D1
# Generation 72: *ELLO, WORdDO
# Generation 73: 7ELLO, WOR^D:
# Generation 74: 5ELLO, WORdDm
# Generation 75: 5ELLO, WORdDs
# Generation 76: *ELLO, WORDDS
# Generation 77: 7ELLO, WORDD{
# Generation 78: *ELLO, WOR_Dy
# Generation 79: *ELLO, WORdDO
# Generation 80: 7ELLO, WORtDO
# Generation 81: *ELLO, WOR^D:
# Generation 82: tELLO, WORDDs
# Generation 83: *ELLO, WOR8Dj
# Generation 84: *ELLO, WORDDI
# Generation 85: *ELLO, WORtD)
# Generation 86: 1ELLO, WOR	D)
# Generation 87: 1ELLO, WOR8Dy
# Generation 88: 7ELLO, WOR8Dy
# Generation 89: tELLO, WOR8Dj
# Generation 90: RELLO, WOR=Dj
# Generation 91: VELLO, WORkD1
# Generation 92: 7ELLO, WOR8Dy
# Generation 93: JELLO, WOR8Dy
# Generation 94: AELLO, WOR^DI
# Generation 95: *ELLO, WOR"Ds
# Generation 96: *ELLO, WORdD1
# Generation 97: HELLO, WOR=Dj
# Generation 98: #ELLO, WORkDy
# Generation 99: *ELLO, WOR^D0
# Generation 100: *ELLO, WOR^D0
# Generation 101: *ELLO, WOR8Dj
# Generation 102: AELLO, WOR^Dc
# Generation 103: *ELLO, WOR=Dj
# Generation 104: 5ELLO, WORkD)
# Generation 105: *ELLO, WOR8DS
# Generation 106: oELLO, WOR8DS
# Generation 107: *ELLO, WORkDs
# Generation 108: *ELLO, WOR=Dy
# Generation 109: *ELLO, WOR8DL
# Generation 110: AELLO, WOR^D)
# Generation 111: *ELLO, WOR8DS
# Generation 112: *ELLO, WOR8Dc
# Generation 113: *ELLO, WOR=DL
# Generation 114: *ELLO, WORDD!
# Generation 115: AELLO, WORDD!
# Generation 116: AELLO, WORDD!
# Generation 117: *ELLO, WORGD!
# Generation 118: AELLO, WORGD!
# Generation 119: *ELLO, WOR?Ds
# Generation 120: *ELLO, WOR^D!
# Generation 121: *ELLO, WOR)D)
# Generation 122: *ELLO, WOR^D!
# Generation 123: *ELLO, WOR?Ds
# Generation 124: *ELLO, WOR8D!
# Generation 125: *ELLO, WOR8D!
# Generation 126: *ELLO, WOR8D!
# Generation 127: *ELLO, WORGD!
# Generation 128: *ELLO, WOR8D!
# Generation 129: AELLO, WOR8D!
# Generation 130: JELLO, WORDD!
# Generation 131: *ELLO, WOR1D!
# Generation 132: *ELLO, WORDD!
# Generation 133: AELLO, WORDD!
# Generation 134: *ELLO, WORDD!
# Generation 135: *ELLO, WOR8D!
# Generation 136: AELLO, WOR[D!
# Generation 137: 9ELLO, WORrD!
# Generation 138: *ELLO, WOR9D!
# Generation 139: *ELLO, WOR^D!
# Generation 140: )ELLO, WOR9D!
# Generation 141: )ELLO, WOR^D!
# Generation 142: PELLO, WORAD!
# Generation 143: AELLO, WOR^D!
# Generation 144: AELLO, WOR|D!
# Generation 145: *ELLO, WOR}D!
# Generation 146: AELLO, WOR=D!
# Generation 147: *ELLO, WORsD!
# Generation 148: AELLO, WOR|D!
# Generation 149: iELLO, WOR9D!
# Generation 150: =ELLO, WOR8D!
# Generation 151: iELLO, WOR8D!
# Generation 152: VELLO, WORrD!
# Generation 153: AELLO, WORAD!
# Generation 154: AELLO, WORAD!
# Generation 155: AELLO, WORKD!
# Generation 156: AELLO, WORrD!
# Generation 157: AELLO, WORcD!
# Generation 158: iELLO, WORcD!
# Generation 159: *ELLO, WORAD!
# Generation 160: *ELLO, WORAD!
# Generation 161: AELLO, WORrD!
# Generation 162: AELLO, WOR8D!
# Generation 163: AELLO, WORED!
# Generation 164: AELLO, WORED!
# Generation 165: *ELLO, WORmD!
# Generation 166: AELLO, WOR-D!
# Generation 167: {ELLO, WORmD!
# Generation 168: HELLO, WORDD!
# Generation 169: AELLO, WOR}D!
# Generation 170: AELLO, WOR8D!
# Generation 171: AELLO, WORrD!
# Generation 172: AELLO, WORrD!
# Generation 173: XELLO, WORrD!
# Generation 174: AELLO, WOR-D!
# Generation 175: HELLO, WORKD!
# Generation 176: XELLO, WORYD!
# Generation 177: HELLO, WOR=D!
# Generation 178: HELLO, WOR}D!
# Generation 179: HELLO, WORYD!
# Generation 180: AELLO, WOR-D!
# Generation 181: *ELLO, WORAD!
# Generation 182: HELLO, WOR-D!
# ELLO, WOR-D!83:
# Generation 184: iELLO, WORSD!
# Generation 185: AELLO, WORSD!
# Generation 186: AELLO, WOR-D!
# Generation 187: iELLO, WOR-D!
# Generation 188: iELLO, WORiD!
# Generation 189: XELLO, WORSD!
# Generation 190: AELLO, WORwD!
# Generation 191: AELLO, WORYD!
# Generation 192: AELLO, WORD!
# Generation 193: CELLO, WOR-D!
# Generation 194: XELLO, WORrD!
# Generation 195: CELLO, WOR-D!
# Generation 196: iELLO, WORD!
# Generation 197: iELLO, WOR-D!
# Generation 198: XELLO, WOR-D!
# Generation 199: XELLO, WORiD!
# Generation 200: dELLO, WOR-D!
# Generation 201: CELLO, WOR-D!
# Generation 202: bELLO, WORwD!
# Generation 203: 8ELLO, WORrD!
# Generation 204: *ELLO, WOR[D!
# Generation 205: XELLO, WORrD!
# Generation 206: bELLO, WORwD!
# Generation 207: XELLO, WORrD!
# Generation 208: bELLO, WORiD!
# Generation 209: 8ELLO, WOR-D!
# Generation 210: bELLO, WOR-D!
# Generation 211: VELLO, WORrD!
# Generation 212: 8ELLO, WORrD!
# Generation 213: *ELLO, WORrD!
# Generation 214: bELLO, WOR-D!
# Generation 215: *ELLO, WOR-D!
# Generation 216: 8ELLO, WOR-D!
# Generation 217: bELLO, WORgD!
# Generation 218: ]ELLO, WOR-D!
# Generation 219: XELLO, WORrD!
# Generation 220: ]ELLO, WOR-D!
# Generation 221: bELLO, WOR-D!
# Generation 222: WELLO, WOR;D!
# Generation 223: XELLO, WORrD!
# Generation 224: ]ELLO, WOR-D!
# Generation 225: bELLO, WOR-D!
# Generation 226: 1ELLO, WOR-D!
# Generation 227: bELLO, WOR-D!
# Generation 228: ]ELLO, WORnD!
# Generation 229: UELLO, WORrD!
# Generation 230: bELLO, WOR-D!
# Generation 231: bELLO, WOR-D!
# Generation 232: bELLO, WOR-D!
# Generation 233: bELLO, WOR-D!
# Generation 234: XELLO, WOR!D!
# Generation 235: XELLO, WOR-D!
# Generation 236: bELLO, WOR4D!
# Generation 237: bELLO, WOR-D!
# Generation 238: bELLO, WORLD!
# Generation 239: -ELLO, WVRLD!
# Generation 240: bELLO, WOR-D!
# Generation 241: bELLO, WORrD!
# Generation 242: 8ELLO, WOR-D!
# Generation 243: bELLO, WORrD!
# Generation 244: bELLO, WORLD!
# Generation 245: bELLO, WORLD!
# Generation 246: xELLO, WORLD!
# Generation 247: bELLO, WORLD!
# Generation 248: bELLO, WORLD!
# Generation 249: XELLO, WORLD!
# Generation 250: XELLO, WORLD!
# Generation 251: ]ELLO, WORLD!
# Generation 252: bELLO, WORLD!
# Generation 253: xELLO, WORLD!
# Generation 254: VELLO, WORLD!
# Generation 255: bELLO, WORLD!
# Generation 256: ]ELLO, WORLD!
# Generation 257: ]ELLO, WORLD!
# Generation 258: XELLO, WORLD!
# Generation 259: XELLO, WORLD!
# Generation 260: wELLO, WORLD!
# Generation 261: bELLO, WORLD!
# Generation 262: wELLO, WORLD!
# Generation 263: bELLO, WORLD!
# Generation 264: bELLO, WORLD!
# Generation 265: wELLO, WORLD!
# Generation 266: 8ELLO, WORLD!
# Generation 267: bELLO, WORLD!
# Generation 268: 6ELLO, WORLD!
# Generation 269: bELLO, WORLD!
# Generation 270: HELLO, WORLD!
